# %%
# Password: jmi@1234
# Problem: Given a URL by the user. 
#     1. Fetch the textual contents from the webpage.
#     2. Perform all the possible cleaning and prepare a text file.
#     3. Prepare a list of 
#         a. paragraphs
#         b. sentences
#         c. words
#         d. unique words
#         e. links.

# %%
from urllib.request import urlopen

url = "https://en.wikipedia.org/wiki/New_Delhi"
page = urlopen(url)
page = page.read().decode("utf-8")

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page, 'html.parser')

# %%
clean_soup = soup.get_text()

# %%
# print(clean_soup)

# %%
import re
whitespaces = re.compile("\n[\n]+[\n]")
clean_soup = re.sub(whitespaces, "\n", clean_soup)

# %%
print(clean_soup)
# Out:
#  New Delhi - Wikipedia Jump to content Main menu Main menu
# move to sidebar
# hide 		Navigation
# 	 Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate 		Contribute
# 	 HelpLearn to editCommunity portalRecent changesUpload file Languages
#
# Language links are at the top of the page. Search Search Create account
#
# Log in Personal tools  Create account Log in 		Pages for logged out editors learn more ContributionsTalk Contents
# move to sidebar
# ...

# %%
from __future__ import print_function
import sys

# %%
# %%capture cap

print(clean_soup)

with open('output.txt', 'w') as file:
    file.write(cap.stdout)

# %%
para = soup.find_all('p')
len(para)
# para
# Out:
# 79

# %%
# print(para)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/uzmafirozkhan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk import sent_tokenize
sentences = sent_tokenize(clean_soup)
count_sent = len(sen)
count_sent
# Out:
# 992

# %%
from nltk.tokenize import word_tokenize
words = word_tokenize(clean_soup)
count_sent = len(words)
count_sent
# Out:
# 17962

# %%
unique_words = []
for w in words:
    if w not in unique_words:
        unique_words.append(w)
        
len(unique_words)
# Out:
# 4214

# %%
# print(unique_words)

# %%
links = soup.find_all('a')
len(links)
# Out:
# 2363
